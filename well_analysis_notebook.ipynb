# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## **Read in CSV Files**:

# %%
train_values_df = pd.read_csv('data/training_set_values.csv')
train_values_df.head(2)
# Out:
#       id  amount_tsh date_recorded   funder  gps_height installer  longitude  \
# 0  69572      6000.0    2011-03-14    Roman        1390     Roman  34.938093
# 1   8776         0.0    2013-03-06  Grumeti        1399   GRUMETI  34.698766
#
#    latitude  wpt_name  num_private  ... payment_type water_quality  \
# 0 -9.856322      none            0  ...     annually          soft
# 1 -2.147466  Zahanati            0  ...    never pay          soft
#
#   quality_group      quantity  quantity_group                source  \
# 0          good        enough          enough                spring
# 1          good  insufficient    insufficient  rainwater harvesting
#
#             source_type  source_class     waterpoint_type  \
# 0                spring   groundwater  communal standpipe
# 1  rainwater harvesting       surface  communal standpipe
#
#   waterpoint_type_group
# 0    communal standpipe
# 1    communal standpipe
#
# [2 rows x 40 columns]

# %%
test_values_df = pd.read_csv('data/test_set_values.csv')
test_values_df.head(2)
# Out:
#       id  amount_tsh date_recorded                  funder  gps_height  \
# 0  50785         0.0    2013-02-04                    Dmdd        1996
# 1  51630         0.0    2013-02-04  Government Of Tanzania        1569
#
#   installer  longitude  latitude                 wpt_name  num_private  ...  \
# 0      DMDD  35.290799 -4.059696  Dinamu Secondary School            0  ...
# 1       DWE  36.656709 -3.309214                  Kimnyak            0  ...
#
#   payment_type water_quality quality_group      quantity  quantity_group  \
# 0    never pay          soft          good      seasonal        seasonal
# 1    never pay          soft          good  insufficient    insufficient
#
#                  source           source_type  source_class  \
# 0  rainwater harvesting  rainwater harvesting       surface
# 1                spring                spring   groundwater
#
#       waterpoint_type waterpoint_type_group
# 0               other                 other
# 1  communal standpipe    communal standpipe
#
# [2 rows x 40 columns]

# %%
submission_format_df = pd.read_csv('data/submission_format.csv')
submission_format_df.head()
# Out:
#       id     status_group
# 0  50785  predicted label
# 1  51630  predicted label
# 2  17168  predicted label
# 3  45559  predicted label
# 4  49871  predicted label

# %%
train_labels_df = pd.read_csv('data/training_set_labels.csv')

# %% [markdown]
# ## **Merging Dataframes Above**

# %%
# merging train_values_df & train_labels_df
train_values_df = pd.merge(train_values_df, train_labels_df, on='id', how='left')
# merging test_values_df & submission_format_df
test_values_df = pd.merge(test_values_df, submission_format_df, on='id', how='left')

# %% [markdown]
# ---

# %% [markdown]
# ## **EDA**

# %%
print(f'train_values_df columns: \n{list(train_values_df.columns)}\n{train_values_df.shape}\n')
print(f'test_values_df columns: \n{list(test_values_df.columns)}\n{test_values_df.shape}\n')
print(f'submission_format_df columns: \n{list(submission_format_df.columns)}\n{submission_format_df.shape}\n')
print(f'train_labels_df columns: \n{list(train_labels_df.columns)}\n{train_labels_df.shape}\n')
# Out:
# train_values_df columns:
# ['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer', 'longitude', 'latitude', 'wpt_name', 'num_private', 'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward', 'population', 'public_meeting', 'recorded_by', 'scheme_management', 'scheme_name', 'permit', 'construction_year', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', 'quantity', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group', 'status_group']
# (59400, 41)
#
# test_values_df columns:
# ['id', 'amount_tsh', 'date_recorded', 'funder', 'gps_height', 'installer', 'longitude', 'latitude', 'wpt_name', 'num_private', 'basin', 'subvillage', 'region', 'region_code', 'district_code', 'lga', 'ward', 'population', 'public_meeting', 'recorded_by', 'scheme_management', 'scheme_name', 'permit', 'construction_year', 'extraction_type', 'extraction_type_group', 'extraction_type_class', 'management', 'management_group', 'payment', 'payment_type', 'water_quality', 'quality_group', 'quantity', 'quantity_group', 'source', 'source_type', 'source_class', 'waterpoint_type', 'waterpoint_type_group', 'status_group']
# (14850, 41)
#
# submission_format_df columns:
# ['id', 'status_group']
# (14850, 2)
#
# train_labels_df columns:
# ['id', 'status_group']
# (59400, 2)

# %% [markdown]
# ---

# %% [markdown]
# ## **Identify Missing Values**

# %% [markdown]
# #### (7) columns with missing values in **train_values_df**:

# %%
train_values_df.isna().sum().sort_values(ascending=False).head(7)
# Out:
# scheme_name          28166
# scheme_management     3877
# installer             3655
# funder                3635
# public_meeting        3334
# permit                3056
# subvillage             371
# dtype: int64

# %% [markdown]
# #### (7) columns with missing values in **test_values_df**:

# %%
test_values_df.isna().sum().sort_values(ascending=False).head(7)
# Out:
# scheme_name          7092
# scheme_management     969
# installer             877
# funder                869
# public_meeting        821
# permit                737
# subvillage             99
# dtype: int64

# %% [markdown]
# #### No values missing in **submission_format_df**:

# %%
submission_format_df.isna().sum().sort_values(ascending=False)
# Out:
# id              0
# status_group    0
# dtype: int64

# %% [markdown]
# #### No values missing in **train_labels_df**:

# %%
train_labels_df.isna().sum().sort_values(ascending=False)
# Out:
# id              0
# status_group    0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## **Data Limitations & Cleaning**

# %% [markdown]
# What we do to **train_values_df** we will do to **test_values_df**:
# 1. **Dropping Columns**:
# - For example, **'scheme_name'** is missing 28,166 values out of 59,400 in train_values_df. As a result, we will drop this column and others we wont need.
# 2. **Dropping rows with missing values**:
# - For rows with a few missing values, we will drop the rows so we can preserve the columns.
# 3. **Data Type Conversion**:
# - The 'date_recorded' column was the only column that needed to be changes to datetime
# 4. **Renaming Columns**:
# - Many of the columns have names that are confusing or dont represent the data. These have been changed.

# %%
# Dropping unneeded columns
dropped_columns = ['scheme_name', 'num_private', 'region_code', 'district_code',
                   'public_meeting', 'recorded_by', 'extraction_type',
                   'extraction_type_group', 'management', 'payment_type',
                   'water_quality', 'quantity_group', 'source_type', 'waterpoint_type'
                   ]
train_values_df = train_values_df.drop(columns=dropped_columns)
test_values_df = test_values_df.drop(columns=dropped_columns)


# Dropping rows with missing values
dropped_rows = ['scheme_management', 'installer','funder', 
                'permit', 'subvillage'
                ]
train_values_df.dropna(subset=dropped_rows, inplace=True)
test_values_df.dropna(subset=dropped_rows, inplace=True)


# Data Type Conversion
train_values_df['date_recorded'] = pd.to_datetime(train_values_df['date_recorded'])
test_values_df['date_recorded'] = pd.to_datetime(test_values_df['date_recorded'])


# Renaming Columns
renamed_col = {'amount_tsh': 'total_static_head(ft)', 'gps_height': 'height',
               'wpt_name': 'waterpoint_name', 'basin': 'basin_location',
               'lga': 'local_gov_area', 'permit': 'permit_approved',
               'extraction_type_class': 'extraction_method',
               'management_group': 'management_type',
               'payment': 'payment_frequency', 'quality_group': 'quality_of_water',
               'quantity': 'quantity_of_water', 'source': 'water_source'
               }
train_values_df = train_values_df.rename(columns=renamed_col)
test_values_df = test_values_df.rename(columns=renamed_col)

# %% [markdown]
# ---

# %% [markdown]
# ## **Sorting Dataframes**

# %%
train_values_df = train_values_df.applymap(lambda s:s.lower() if type(s) == str else s)

# %% [markdown]
# ## Maddie's Filtering

# %%
train_values_df['date_recorded'].value_counts()
train_values_df['year_recorded'] = train_values_df['date_recorded'].apply(lambda x: x.year)

# %%
train_values_df['year_recorded'].value_counts()
# Out:
# 2011    24256
# 2013    21163
# 2012     5473
# 2004       25
# 2002        1
# Name: year_recorded, dtype: int64

# %%
train_values_df['well_age'] = train_values_df['year_recorded'] - train_values_df['construction_year']

# %%
construction_null = train_values_df[train_values_df['construction_year'] == 0]

display_all(construction_null.head(20))
# Out:
#        id  total_static_head(ft) date_recorded                  funder  \
# 6   19816                    0.0    2012-10-01                    dwsp
# 8   53934                    0.0    2012-11-03                wateraid
# 12  36957                    0.0    2012-10-14            world vision
# 14  53752                    0.0    2012-10-20                   biore
# 21   6091                    0.0    2013-02-10                    dwsp
# 30  46804                    0.0    2011-03-23                   water
# 36  67359                    0.0    2011-07-16                  danida
# 37  60048                    0.0    2011-03-27                   kirde
# 45  12958                    0.0    2012-10-22            world vision
# 52  10745                    0.0    2011-07-31            kkkt_makwale
# 53  32376                    0.0    2011-08-01  government of tanzania
# 59  31714                    0.0    2011-07-07  government of tanzania
# 67  22108                    0.0    2011-07-31  government of tanzania
# 79  52561                    0.0    2012-10-23            world vision
# 83  34383                    0.0    2012-10-22                   rwssp
# 85  68717                    0.0    2011-08-08                 swedish
# 89  22143                    0.0    2011-04-11                   water
# 94  48593                    0.0    2011-07-11                  hesawa
# 97  29083                    0.0    2011-08-04                 mzee sh
# 99  43206                    0.0    2012-10-06                    aict
#
#     height                   installer  longitude      latitude  \
# 6        0                        dwsp  33.362410 -3.766365e+00
# 8        0                   water aid  32.711100 -5.146712e+00
# 12       0                world vision  33.798106 -3.290194e+00
# 14       0                      wedeco  34.364073 -3.629333e+00
# 21       0                         dwe   0.000000 -2.000000e-08
# 30       0                       water  36.108312 -5.791000e+00
# 36       0          central government  33.854345 -9.638520e+00
# 37       0                         dwe  35.858373 -4.647906e+00
# 45       0                world vision  33.345260 -3.838998e+00
# 52       0        kkkt _ konde and dwe  33.958163 -9.448122e+00
# 53       0                  government   0.000000 -2.000000e-08
# 59       0                         dwe  31.454282 -1.563886e+00
# 67       0                         dwe  30.716090 -1.285780e+00
# 79       0                world vision  32.255005 -3.361901e+00
# 83       0                         dwe  33.538909 -3.361612e+00
# 85       0  sengerema water department  32.185517 -2.378772e+00
# 89       0                       commu  35.878172 -5.891868e+00
# 94       0                         dwe  31.453111 -1.194390e+00
# 97       0                       allys  33.079504 -3.009659e+00
# 99       0                        aict  33.235838 -3.566020e+00
#
#         waterpoint_name   basin_location          subvillage     region  \
# 6            kwa ngomho         internal       ishinabulandi  shinyanga
# 8     kwa ramadhan musa  lake tanganyika          imalauduki     tabora
# 12                pamba         internal             nkilifa  shinyanga
# 14            mwabasabi         internal           mwabasabi  shinyanga
# 21             muungano    lake victoria          ibabachegu  shinyanga
# 30                ngosi      wami / ruvu              karume     dodoma
# 36     office ya kijiji       lake nyasa         ndanganyika      mbeya
# 37                tangi         internal               baura     dodoma
# 45              shimasa         internal           isenegeja  shinyanga
# 52  kwa abeli mwamakula       lake nyasa              isimba      mbeya
# 53               polisi    lake victoria              center     mwanza
# 59         kwa mzee max    lake victoria         izimbya 'a'     kagera
# 67             kwashuza    lake victoria             kihanga     kagera
# 79              butimba  lake tanganyika             butimba  shinyanga
# 83                lembo         internal             bushoma  shinyanga
# 85          kwa swakala    lake victoria  bulyahilu center b     mwanza
# 89              ofisini      wami / ruvu              juhudi     dodoma
# 94            kagashani    lake victoria            mushasha     kagera
# 97             kwa shij    lake victoria            misasi c     mwanza
# 99  kwa daudi mandusela         internal          madukani a  shinyanga
#
#      local_gov_area               ward  population scheme_management  \
# 6   shinyanga rural             samuye           0               vwc
# 8      tabora urban           itetemia           0               vwc
# 12            maswa           busilili           0               wug
# 14            meatu              nkoma           0               wug
# 21          bariadi  ikungulyabashashi           0               wug
# 30         chamwino             dabalo           0               vwc
# 36            kyela      katumbasongwe           0               vwc
# 37           kondoa             mnenia           0               vwc
# 45  shinyanga rural             samuye           0               wug
# 52            kyela            makwale           0               vwc
# 53            geita        nyang'hwale           0               vwc
# 59     bukoba rural            izimbya           0               vwc
# 67          karagwe           isingiro           0               wug
# 79          bukombe           ushirika           0               vwc
# 83          kishapu              mondo           0               wug
# 85        sengerema      bupandwamhela           0               vwc
# 89     dodoma urban           chihanga           0               vwc
# 94          misenyi              kyaka           0               vwc
# 97        missungwi             misasi           0  private operator
# 99  shinyanga rural           mwantini           0               vwc
#
#     permit_approved  construction_year extraction_method management_type  \
# 6              True                  0          handpump      user-group
# 8              True                  0          handpump      user-group
# 12            False                  0          handpump      user-group
# 14             True                  0          handpump      user-group
# 21            False                  0          handpump      user-group
# 30             True                  0          handpump      user-group
# 36             True                  0           gravity      user-group
# 37            False                  0           gravity      user-group
# 45             True                  0      wind-powered      user-group
# 52             True                  0           gravity      user-group
# 53             True                  0       submersible      user-group
# 59             True                  0          handpump      user-group
# 67             True                  0           gravity      user-group
# 79             True                  0          handpump      user-group
# 83            False                  0          handpump      user-group
# 85             True                  0          handpump      user-group
# 89            False                  0         motorpump      user-group
# 94             True                  0          handpump      user-group
# 97             True                  0       submersible      commercial
# 99            False                  0         motorpump      user-group
#
#         payment_frequency quality_of_water quantity_of_water  water_source  \
# 6               never pay             good            enough   machine dbh
# 8               never pay            salty          seasonal   machine dbh
# 12                  other             good            enough  shallow well
# 14              never pay             good            enough  shallow well
# 21                unknown          unknown           unknown  shallow well
# 30              never pay             good      insufficient  shallow well
# 36              never pay             good               dry        spring
# 37            pay monthly             good            enough        spring
# 45  pay when scheme fails             good            enough   machine dbh
# 52              never pay             good            enough        spring
# 53                unknown          unknown               dry   machine dbh
# 59              never pay             good            enough  shallow well
# 67              never pay             good               dry        spring
# 79                unknown             good      insufficient  shallow well
# 83  pay when scheme fails             good      insufficient  shallow well
# 85              never pay             good          seasonal  shallow well
# 89         pay per bucket             good      insufficient   machine dbh
# 94              never pay            milky      insufficient  shallow well
# 97         pay per bucket          unknown            enough   machine dbh
# 99              never pay             good            enough           dam
#
#    source_class waterpoint_type_group             status_group  year_recorded  \
# 6   groundwater             hand pump           non functional           2012
# 8   groundwater             hand pump           non functional           2012
# 12  groundwater             hand pump               functional           2012
# 14  groundwater             hand pump               functional           2012
# 21  groundwater             hand pump               functional           2013
# 30  groundwater             hand pump               functional           2011
# 36  groundwater    communal standpipe           non functional           2011
# 37  groundwater    communal standpipe               functional           2011
# 45  groundwater    communal standpipe           non functional           2012
# 52  groundwater    communal standpipe               functional           2011
# 53  groundwater    communal standpipe           non functional           2011
# 59  groundwater             hand pump  functional needs repair           2011
# 67  groundwater                 other           non functional           2011
# 79  groundwater             hand pump               functional           2012
# 83  groundwater             hand pump               functional           2012
# 85  groundwater             hand pump           non functional           2011
# 89  groundwater    communal standpipe  functional needs repair           2011
# 94  groundwater             hand pump           non functional           2011
# 97  groundwater    communal standpipe               functional           2011
# 99      surface    communal standpipe           non functional           2012
#
#     well_age
# 6       2012
# 8       2012
# 12      2012
# 14      2012
# 21      2013
# 30      2011
# 36      2011
# 37      2011
# 45      2012
# 52      2011
# 53      2011
# 59      2011
# 67      2011
# 79      2012
# 83      2012
# 85      2011
# 89      2011
# 94      2011
# 97      2011
# 99      2012

# %%
train_values_df[train_values_df['status_group'] == 'functional needs repair'] = "functional"

# %%
train_values_df['status_group'].value_counts()
# Out:
# functional        31467
# non functional    19451
# Name: status_group, dtype: int64

# %%
train_values_df.columns
# Out:
# Index(['id', 'total_static_head(ft)', 'date_recorded', 'funder', 'height',
#        'installer', 'longitude', 'latitude', 'waterpoint_name',
#        'basin_location', 'subvillage', 'region', 'local_gov_area', 'ward',
#        'population', 'scheme_management', 'permit_approved',
#        'construction_year', 'extraction_method', 'management_type',
#        'payment_frequency', 'quality_of_water', 'quantity_of_water',
#        'water_source', 'source_class', 'waterpoint_type_group', 'status_group',
#        'year_recorded'],
#       dtype='object')

# %%
my_df = train_values_df[['extraction_method', 'management_type',
       'payment_frequency', 'quality_of_water', 'quantity_of_water',
       'water_source', 'source_class', 'waterpoint_type_group',
       'status_group']]

# %%
#drop payment_frequency
my_df.drop('payment_frequency', axis=1, inplace=True)

#if unknown makes up less than 1%, drop unknown rows from our table 
def drop_unknown(df, column):
    counts = df[column].value_counts(normalize=True)
    if 'unknown' in counts.index and counts['unknown'] < 0.01:
        df.drop(df[df[column] == 'unknown'].index, inplace=True)

#loop through columns to drop unknowns
for column in my_df.columns: 
    drop_unknown(my_df, column)
# Out:
# /var/folders/qh/ns54bt951q74xt4l68nw_m840000gn/T/ipykernel_84899/863275260.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_df.drop('payment_frequency', axis=1, inplace=True)

# %%
my_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50234 entries, 0 to 59399
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   extraction_method      50234 non-null  object
#  1   management_type        50234 non-null  object
#  2   quality_of_water       50234 non-null  object
#  3   quantity_of_water      50234 non-null  object
#  4   water_source           50234 non-null  object
#  5   source_class           50234 non-null  object
#  6   waterpoint_type_group  50234 non-null  object
#  7   status_group           50234 non-null  object
# dtypes: object(8)
# memory usage: 3.4+ MB

# %%
my_df['source_class'].value_counts(normalize=True)
# Out:
# groundwater    0.769698
# surface        0.230302
# Name: source_class, dtype: float64

# %%
# Function that displays all columns and rows when you use commands like df.head() and df_tail().

def display_all(df):
    with pd.option_context('display.max_rows', 1000):
        with pd.option_context('display.max_columns', 1000):
            display(df)

# %%
display_all(train_values_df.head(100))
